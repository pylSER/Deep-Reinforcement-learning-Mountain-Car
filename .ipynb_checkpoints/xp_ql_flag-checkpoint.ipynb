# %%
import numpy as np
import matplotlib.pyplot as plt

def getStateToRC(state):
    r = state // 6
    c = state % 6
    return r, c

def getRCToState(r, c):
    return int(r*6 + c)

def xp_step(state, action):
    r, c = getStateToRC(state)
    if (r>0 and action == 0):
        r-=1
    if (r<3 and action == 1):
        r+=1
    if (c>1 and action == 2):
        c-=1
    if (c<5 and action == 3):
        c+=1

    state2 = getRCToState(r, c)
    done = False
    reward = -10
    if (state2 == 13):
        done = True
        reward = 100
    return state2, reward, done

env = []

# Define Q-learning function
def QLearning(env, learning, discount, epsilon, min_eps, episodes):
    # Determine size of discretized state space
    num_states = 24
    
    # Initialize Q table
    Q = np.random.uniform(low = -1, high = 1, 
                          size = (24, 4))
    
    # Initialize variables to track rewards
    reward_list = []
    ave_reward_list = []
    
    # Calculate episodic reduction in epsilon
    reduction = (epsilon - min_eps)/episodes
    
    # Run Q learning algorithm
    for i in range(episodes):
        # Initialize parameters
        done = False
        tot_reward, reward = 0,0
        state = np.random.randint(0, 23)
    
        while done != True:                  
            # Determine next action - epsilon greedy strategy
            if np.random.random() < 1 - epsilon:
                action = np.argmax(Q[state]) 
            else:
                action = np.random.randint(0, 3)
                
            # Get next state and reward
            state2, reward, done = xp_step(state, action) 
 
            #Allow for terminal states
            if done:
                Q[state, action] = reward
                
            # Adjust Q value for current state
            else:
                delta = learning * (reward + discount * np.max(Q[state2]) - Q[state, action])
                Q[state, action] += delta
                                     
            # Update variables
            tot_reward += reward
            state = state2
        
        # Decay epsilon
        if epsilon > min_eps:
            epsilon -= reduction
        
        # Track rewards
        reward_list.append(tot_reward)
        
        if (i+1) % 100 == 0:
            ave_reward = np.mean(reward_list)
            ave_reward_list.append(ave_reward)
            reward_list = []
            
        if (i+1) % 100 == 0:    
            print('Episode {} Average Reward: {}'.format(i+1, ave_reward))
            
    # env.close()
    
    return ave_reward_list

# %%
# Run Q-learning algorithm
rewards = QLearning(env, 0.2, 0.9, 0.8, 0, 10000)
# Out:
# Episode 100 Average Reward: 16.7
# Episode 200 Average Reward: 34.3
# Episode 300 Average Reward: 17.2
# Episode 400 Average Reward: 38.1
# Episode 500 Average Reward: 36.9
# Episode 600 Average Reward: 39.8
# Episode 700 Average Reward: 40.9
# Episode 800 Average Reward: 50.8
# Episode 900 Average Reward: 42.9
# Episode 1000 Average Reward: 47.3
# Episode 1100 Average Reward: 47.2
# Episode 1200 Average Reward: 42.1
# Episode 1300 Average Reward: 52.7
# Episode 1400 Average Reward: 51.2
# Episode 1500 Average Reward: 58.3
# Episode 1600 Average Reward: 53.5
# Episode 1700 Average Reward: 52.0
# Episode 1800 Average Reward: 52.0
# Episode 1900 Average Reward: 48.5
# Episode 2000 Average Reward: 56.1
# Episode 2100 Average Reward: 62.7
# Episode 2200 Average Reward: 61.9
# Episode 2300 Average Reward: 55.4
# Episode 2400 Average Reward: 59.0
# Episode 2500 Average Reward: 60.2
# Episode 2600 Average Reward: 60.1
# Episode 2700 Average Reward: 56.9
# Episode 2800 Average Reward: 57.4
# Episode 2900 Average Reward: 56.6
# Episode 3000 Average Reward: 63.8
# Episode 3100 Average Reward: 63.2
# Episode 3200 Average Reward: 62.3
# Episode 3300 Average Reward: 66.3
# Episode 3400 Average Reward: 62.9
# Episode 3500 Average Reward: 65.4
# Episode 3600 Average Reward: 65.4
# Episode 3700 Average Reward: 62.2
# Episode 3800 Average Reward: 67.4
# Episode 3900 Average Reward: 66.5
# Episode 4000 Average Reward: 75.8
# Episode 4100 Average Reward: 69.7
# Episode 4200 Average Reward: 68.0
# Episode 4300 Average Reward: 73.2
# Episode 4400 Average Reward: 70.7
# Episode 4500 Average Reward: 71.1
# Episode 4600 Average Reward: 68.8
# Episode 4700 Average Reward: 69.9
# Episode 4800 Average Reward: 66.0
# Episode 4900 Average Reward: 72.7
# Episode 5000 Average Reward: 73.5
# Episode 5100 Average Reward: 70.0
# Episode 5200 Average Reward: 70.9
# Episode 5300 Average Reward: 69.6
# Episode 5400 Average Reward: 72.8
# Episode 5500 Average Reward: 75.0
# Episode 5600 Average Reward: 75.7
# Episode 5700 Average Reward: 74.7
# Episode 5800 Average Reward: 72.1
# Episode 5900 Average Reward: 73.7
# Episode 6000 Average Reward: 70.1
# Episode 6100 Average Reward: 74.1
# Episode 6200 Average Reward: 77.5
# Episode 6300 Average Reward: 74.5
# Episode 6400 Average Reward: 78.0
# Episode 6500 Average Reward: 73.3
# Episode 6600 Average Reward: 79.0
# Episode 6700 Average Reward: 80.8
# Episode 6800 Average Reward: 79.4
# Episode 6900 Average Reward: 78.5
# Episode 7000 Average Reward: 79.6
# Episode 7100 Average Reward: 80.2
# Episode 7200 Average Reward: 80.9
# Episode 7300 Average Reward: 78.0
# Episode 7400 Average Reward: 81.2
# Episode 7500 Average Reward: 82.5
# Episode 7600 Average Reward: 81.2
# Episode 7700 Average Reward: 80.1
# Episode 7800 Average Reward: 81.1
# Episode 7900 Average Reward: 82.3
# Episode 8000 Average Reward: 83.5

# %%
# Plot Rewards
plt.plot(100*(np.arange(len(rewards)) + 1), rewards)
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Average Reward vs Episodes')
# plt.savefig('rewards.jpg')     
# plt.close()
# Out:
# Text(0.5, 1.0, 'Average Reward vs Episodes')
