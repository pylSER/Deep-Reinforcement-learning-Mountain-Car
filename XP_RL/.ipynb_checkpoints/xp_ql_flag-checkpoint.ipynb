# %%
'''
RL to capture a hidden flag
'''
import numpy as np
import matplotlib.pyplot as plt

# %%
# Grid environment 
COL = 10 ## 6 10 12. 15 fail
ROW = 10 ## 4 10 12. 15 fail

NUM_STATES = COL * ROW
NUM_ACTIONS = 4 # up down left right

FLAG_STATE = 13 # preset flag location. Must be less than COL * ROW

REWARD_FAIL = -10
REWARD_SUCCCESS = 100

## convert state to row and column
def getStateToRC(state):
    r = state // COL ## col
    c = state % COL
    return r, c

## get state from row and column
def getRCToState(r, c):
    return int(r*COL + c)

## step function
def xp_step(state, action):
    r, c = getStateToRC(state)
    
    if (r > 0 and action == 0): ## 4 actions: up down left right
        r-=1
    if (r < ROW-1 and action == 1):
        r+=1
    if (c > 1 and action == 2):
        c-=1
    if (c < COL-1 and action == 3):
        c+=1

    state_new = getRCToState(r, c)
    done = False
    
    reward = REWARD_FAIL
    
    if (state_new == FLAG_STATE):  ## fixed place
        done = True
        reward = REWARD_SUCCCESS
        
    return state_new, reward, done


env = []


# Define Q-learning function
def QLearning(env, learning, discount, epsilon, min_eps, episodes):
    # Determine size of discretized state space
    
    # Initialize Q table
    Q = np.random.uniform(low = -1, high = 1, 
                          size = (NUM_STATES, NUM_ACTIONS)) 
    
    # Initialize variables to track rewards
    reward_list = []
    avg_reward_list = []
    
    # Calculate episodic decay in epsilon
    decay = (epsilon - min_eps)/episodes
    
    # Run Q learning algorithm
    for i in range(episodes):
        # Initialize parameters
        done = False
        total_reward, reward = 0, 0
        state = np.random.randint(0, NUM_STATES -1) # random
    
        while done != True:                  
            # Determine the next action - epsilon greedy strategy
            if np.random.random() < 1 - epsilon:
                action = np.argmax(Q[state]) 
            else:
                action = np.random.randint(0, NUM_ACTIONS -1) 
                
            # Get next state and reward
            state_new, reward, done = xp_step(state, action) 
 
            #Allow for terminal states
            if done:
                Q[state, action] = reward
                
            # Adjust Q value for current state
            else:
                delta = learning * (reward + discount * np.max(Q[state_new]) - Q[state, action])
                Q[state, action] += delta
                                     
            # Update variables
            total_reward += reward
            state = state_new
        
        # Decay epsilon
        if epsilon > min_eps:
            epsilon -= decay
        
        # Track rewards
        reward_list.append(total_reward)
        
        if (i+1) % 100 == 0: # sample rewards
            avg_reward = np.mean(reward_list)
            avg_reward_list.append(avg_reward)
            reward_list = []
            
        if (i+1) % 100 == 0:    
            print('Episode {} Average Reward: {}'.format(i+1, avg_reward))
            
    # env.close()
    
    return avg_reward_list, Q

# %%
# Run Q-learning algorithm
rewards, Q = QLearning(env, 0.2, 0.9, 0.8, 0, 10000)
# Out:
# Episode 100 Average Reward: -597.4
# Episode 200 Average Reward: -593.2
# Episode 300 Average Reward: -404.9
# Episode 400 Average Reward: -385.5
# Episode 500 Average Reward: -424.5
# Episode 600 Average Reward: -392.0
# Episode 700 Average Reward: -349.9
# Episode 800 Average Reward: -270.2
# Episode 900 Average Reward: -319.0
# Episode 1000 Average Reward: -296.3
# Episode 1100 Average Reward: -262.0
# Episode 1200 Average Reward: -188.4
# Episode 1300 Average Reward: -216.2
# Episode 1400 Average Reward: -227.2
# Episode 1500 Average Reward: -240.6
# Episode 1600 Average Reward: -192.2
# Episode 1700 Average Reward: -172.3
# Episode 1800 Average Reward: -132.3
# Episode 1900 Average Reward: -157.8
# Episode 2000 Average Reward: -186.3
# Episode 2100 Average Reward: -142.2
# Episode 2200 Average Reward: -126.2
# Episode 2300 Average Reward: -127.4
# Episode 2400 Average Reward: -86.9
# Episode 2500 Average Reward: -101.0
# Episode 2600 Average Reward: -94.1
# Episode 2700 Average Reward: -85.2
# Episode 2800 Average Reward: -80.6
# Episode 2900 Average Reward: -67.2
# Episode 3000 Average Reward: -46.0
# Episode 3100 Average Reward: -70.6
# Episode 3200 Average Reward: -49.3
# Episode 3300 Average Reward: -50.2
# Episode 3400 Average Reward: -55.3
# Episode 3500 Average Reward: -44.1
# Episode 3600 Average Reward: -46.0
# Episode 3700 Average Reward: -43.5
# Episode 3800 Average Reward: -28.0
# Episode 3900 Average Reward: -33.5
# Episode 4000 Average Reward: -18.1
# Episode 4100 Average Reward: -29.6
# Episode 4200 Average Reward: -31.8
# Episode 4300 Average Reward: -26.9
# Episode 4400 Average Reward: -12.7
# Episode 4500 Average Reward: -18.4
# Episode 4600 Average Reward: -14.0
# Episode 4700 Average Reward: -18.7
# Episode 4800 Average Reward: -3.7
# Episode 4900 Average Reward: -18.0
# Episode 5000 Average Reward: 0.4
# Episode 5100 Average Reward: -1.1
# Episode 5200 Average Reward: -9.8
# Episode 5300 Average Reward: -2.9
# Episode 5400 Average Reward: -1.0
# Episode 5500 Average Reward: 5.6
# Episode 5600 Average Reward: -5.1
# Episode 5700 Average Reward: 10.3
# Episode 5800 Average Reward: 5.4
# Episode 5900 Average Reward: -2.7
# Episode 6000 Average Reward: 14.3
# Episode 6100 Average Reward: 13.0
# Episode 6200 Average Reward: 16.7
# Episode 6300 Average Reward: 6.9
# Episode 6400 Average Reward: 8.5
# Episode 6500 Average Reward: 14.3
# Episode 6600 Average Reward: 8.8
# Episode 6700 Average Reward: 16.8
# Episode 6800 Average Reward: 21.1
# Episode 6900 Average Reward: 16.3
# Episode 7000 Average Reward: 19.3
# Episode 7100 Average Reward: 31.7
# Episode 7200 Average Reward: 28.8
# Episode 7300 Average Reward: 28.4
# Episode 7400 Average Reward: 28.2
# Episode 7500 Average Reward: 23.0
# Episode 7600 Average Reward: 33.1
# Episode 7700 Average Reward: 26.3
# Episode 7800 Average Reward: 28.2
# Episode 7900 Average Reward: 30.5
# Episode 8000 Average Reward: 33.5
# Episode 8100 Average Reward: 35.4
# Episode 8200 Average Reward: 31.9
# Episode 8300 Average Reward: 35.0
# Episode 8400 Average Reward: 34.1
# Episode 8500 Average Reward: 36.9
# Episode 8600 Average Reward: 30.2
# Episode 8700 Average Reward: 32.4
# Episode 8800 Average Reward: 37.4
# Episode 8900 Average Reward: 43.7
# Episode 9000 Average Reward: 40.5
# Episode 9100 Average Reward: 40.9
# Episode 9200 Average Reward: 47.0
# Episode 9300 Average Reward: 38.3
# Episode 9400 Average Reward: 43.9
# Episode 9500 Average Reward: 45.7
# Episode 9600 Average Reward: 45.6
# Episode 9700 Average Reward: 48.9
# Episode 9800 Average Reward: 44.1
# Episode 9900 Average Reward: 46.6
# Episode 10000 Average Reward: 49.1

# %%
# Plot Rewards
plt.plot(100*(np.arange(len(rewards)) + 1), rewards)
plt.xlabel('Episodes')
plt.ylabel('Average Reward')
plt.title('Average Reward vs Episodes')
# plt.savefig('rewards.jpg')     
# plt.close()
# Out:
# Text(0.5, 1.0, 'Average Reward vs Episodes')

# %%
print (Q)
# Out:
# [[ 3.12090454e+01  4.57900745e+01  3.12031020e+01  4.58000000e+01]
#  [ 4.58000000e+01  6.20000000e+01  4.58000000e+01  1.34659736e+00]
#  [ 6.20000000e+01  8.00000000e+01  4.58000000e+01  6.00803154e-01]
#  [ 7.99971457e+01  1.00000000e+02  6.19999372e+01  3.62626857e+00]
#  [ 6.20000000e+01  8.00000000e+01  8.00000000e+01 -4.18561340e-01]
#  [ 4.58000000e+01  6.19999894e+01  6.20000000e+01 -1.90195718e-01]
#  [ 3.12197881e+01  4.57998426e+01  4.58000000e+01  7.65280388e-01]
#  [ 1.80979439e+01  3.12200000e+01  3.12199892e+01 -1.82925859e+00]
#  [ 6.27632539e+00  1.80812089e+01  1.80980000e+01 -9.82462555e+00]
#  [-4.41406328e+00  3.67849339e+00  6.28820000e+00 -1.26675873e+01]
#  [ 3.12197268e+01  3.12191633e+01  4.57962648e+01  6.20000000e+01]
#  [ 4.58000000e+01  4.58000000e+01  6.20000000e+01  8.00000000e+01]
#  [ 6.20000000e+01  6.20000000e+01  6.20000000e+01  1.00000000e+02]
#  [ 7.99999957e+01  7.77247209e+01  7.64539467e+01 -7.69378389e-01]
#  [ 6.20000000e+01  6.20000000e+01  1.00000000e+02 -1.13090068e-01]
#  [ 4.58000000e+01  4.58000000e+01  8.00000000e+01 -7.57569709e-01]
#  [ 3.12199999e+01  3.12200000e+01  6.20000000e+01  7.07517461e-02]
#  [ 1.80980000e+01  1.80979975e+01  4.58000000e+01 -2.52972539e+00]
#  [ 6.28375832e+00  6.28711230e+00  3.12200000e+01 -8.09342828e+00]
#  [-4.93331187e+00 -5.24960170e+00  1.80980000e+01 -1.41970939e+01]
#  [ 4.58000000e+01  1.80922557e+01  3.12106428e+01  4.51321985e+01]
#  [ 6.20000000e+01  3.12200000e+01  4.58000000e+01  3.91456833e+01]
#  [ 8.00000000e+01  4.58000000e+01  4.58000000e+01  7.64505615e+01]
#  [ 1.00000000e+02  6.20000000e+01  6.20000000e+01 -8.57211096e-02]
#  [ 8.00000000e+01  4.58000000e+01  8.00000000e+01 -5.01330813e-01]
#  [ 6.20000000e+01  3.12200000e+01  6.20000000e+01 -2.02265815e+00]
#  [ 4.58000000e+01  1.80980000e+01  4.58000000e+01 -2.36828910e+00]
#  [ 3.12199943e+01  6.28819967e+00  3.12200000e+01 -8.11302958e+00]
#  [ 1.80941014e+01 -4.34116209e+00  1.80980000e+01 -9.62992217e+00]
#  [ 3.55466553e+00 -1.39953740e+01  6.28819998e+00 -1.30032344e+01]
#  [ 3.11981511e+01  6.28747341e+00  1.80916148e+01  3.12200000e+01]
#  [ 4.58000000e+01  1.80980000e+01  3.12200000e+01 -5.47883549e+00]
#  [ 6.20000000e+01  3.12200000e+01  3.12200000e+01 -1.67030205e+00]
#  [ 8.00000000e+01  4.58000000e+01  4.58000000e+01  5.03095945e-01]
#  [ 6.20000000e+01  3.12200000e+01  6.20000000e+01 -5.76983940e-02]
#  [ 4.58000000e+01  1.80980000e+01  4.58000000e+01 -2.67119712e+00]
#  [ 3.12199998e+01  6.28819973e+00  3.12200000e+01 -4.04930324e+00]
#  [ 1.80979984e+01 -4.34062284e+00  1.80980000e+01 -9.46402985e+00]
#  [ 6.28645447e+00 -1.39117959e+01  6.28820000e+00 -1.07403907e+01]
#  [-5.63410843e+00 -2.25734341e+01 -4.34062000e+00 -1.67482721e+01]
#  [ 1.80980000e+01 -4.34408654e+00  6.26102856e+00  6.81591261e+00]
#  [ 3.12200000e+01  6.28820000e+00  1.80980000e+01 -5.49793077e+00]
#  [ 4.58000000e+01  1.80980000e+01  1.80980000e+01 -4.50564738e+00]
#  [ 6.20000000e+01  3.12200000e+01  3.12200000e+01 -2.17486738e+00]
#  [ 4.58000000e+01  1.80980000e+01  4.58000000e+01 -2.85739410e+00]
#  [ 3.12200000e+01  6.28820000e+00  3.12200000e+01 -7.40733997e+00]
#  [ 1.80979993e+01 -4.34062180e+00  1.80980000e+01 -1.18103703e+01]
#  [ 6.28812844e+00 -1.39067067e+01  6.28820000e+00 -1.36505722e+01]
#  [-4.34322783e+00 -2.25234612e+01 -4.34062000e+00 -1.76660404e+01]
#  [-1.43177577e+01 -3.04328249e+01 -1.39065580e+01 -2.22534009e+01]
#  [ 6.21193769e+00 -1.39019533e+01 -4.34614110e+00  6.28820000e+00]
#  [ 1.80980000e+01 -4.34062000e+00  6.28820000e+00 -1.40478828e+01]
#  [ 3.12200000e+01  6.28820000e+00  6.28820000e+00 -7.75409209e+00]
#  [ 4.58000000e+01  1.80980000e+01  1.80980000e+01 -3.29754025e+00]
#  [ 3.12200000e+01  6.28820000e+00  3.12200000e+01 -7.41357784e+00]
#  [ 1.80980000e+01 -4.34062000e+00  1.80980000e+01 -1.25528924e+01]
#  [ 6.28819950e+00 -1.39065591e+01  6.28820000e+00 -1.42026800e+01]
#  [-4.34077478e+00 -2.25159616e+01 -4.34062000e+00 -2.05367472e+01]
#  [-1.39075932e+01 -3.02653873e+01 -1.39065580e+01 -2.23873301e+01]
#  [-2.27970245e+01 -3.68819901e+01 -2.25159025e+01 -2.80592692e+01]
#  [-4.34656710e+00 -2.25077948e+01 -1.39054925e+01 -4.34062000e+00]
#  [ 6.28820000e+00 -1.39065580e+01 -4.34062000e+00 -1.25485204e+01]
#  [ 1.80980000e+01 -4.34062000e+00 -4.34062000e+00 -1.08158595e+01]
#  [ 3.12200000e+01  6.28820000e+00  6.28820000e+00 -1.12150749e+01]
#  [ 1.80980000e+01 -4.34062000e+00  1.80980000e+01 -1.16968007e+01]
#  [ 6.28820000e+00 -1.39065580e+01  6.28820000e+00 -1.61074266e+01]
#  [-4.34062000e+00 -2.25159022e+01 -4.34062000e+00 -1.99873865e+01]
#  [-1.39075846e+01 -3.02644438e+01 -1.39065580e+01 -2.62803172e+01]
#  [-2.25199945e+01 -3.72377166e+01 -2.25159022e+01 -2.87745630e+01]
#  [-3.04483464e+01 -4.29029994e+01 -3.02643121e+01 -3.31313055e+01]
#  [-1.39065580e+01 -3.02490320e+01 -2.25055454e+01 -1.39065580e+01]
#  [-4.34062000e+00 -2.25159022e+01 -1.39065580e+01 -1.45610342e+01]
#  [ 6.28820000e+00 -1.39065580e+01 -1.39065580e+01 -1.51259546e+01]
#  [ 1.80980000e+01 -4.34062000e+00 -4.34062000e+00 -1.31509070e+01]
#  [ 6.28820000e+00 -1.39065580e+01  6.28820000e+00 -1.64661403e+01]
#  [-4.34062000e+00 -2.25159024e+01 -4.34062182e+00 -2.05328516e+01]
#  [-1.39065580e+01 -3.02643120e+01 -1.39065580e+01 -2.64136531e+01]
#  [-2.25159539e+01 -3.72378821e+01 -2.25159022e+01 -3.07187511e+01]
#  [-3.02674086e+01 -4.35126282e+01 -3.02643120e+01 -3.40412807e+01]
#  [-3.72633036e+01 -4.89839808e+01 -3.72378808e+01 -3.78090617e+01]
#  [-2.25159018e+01 -3.71534947e+01 -3.02127021e+01 -2.25159018e+01]
#  [-1.39065580e+01 -3.02643120e+01 -2.25159022e+01 -1.73176275e+01]
#  [-4.34062000e+00 -2.25159022e+01 -2.25159022e+01 -2.25262868e+01]
#  [ 6.28820000e+00 -1.39065580e+01 -1.39065580e+01 -2.00838507e+01]
#  [-4.34062000e+00 -2.25159022e+01 -4.34062000e+00 -2.26468995e+01]
#  [-1.39065580e+01 -3.02643120e+01 -1.39065580e+01 -2.46703585e+01]
#  [-2.25159023e+01 -3.72378810e+01 -2.25159022e+01 -2.87180791e+01]
#  [-3.02643122e+01 -4.35140911e+01 -3.02643120e+01 -3.25527471e+01]
#  [-3.72453743e+01 -4.90357492e+01 -3.72378808e+01 -3.86739695e+01]
#  [-4.35140813e+01 -4.88785181e+01 -4.35140818e+01 -4.42922657e+01]
#  [-3.02642296e+01 -3.70030717e+01 -3.69476180e+01 -3.02642179e+01]
#  [-2.25159022e+01 -3.02643120e+01 -3.02643120e+01 -2.42321767e+01]
#  [-1.39065580e+01 -2.25159031e+01 -3.02643110e+01 -2.58845228e+01]
#  [-4.34062000e+00 -1.39065709e+01 -2.25159133e+01 -2.40079399e+01]
#  [-1.39065580e+01 -2.25159063e+01 -1.39065671e+01 -2.58493349e+01]
#  [-2.25159022e+01 -3.02643141e+01 -2.25159022e+01 -3.04376186e+01]
#  [-3.02711266e+01 -3.72382071e+01 -3.02643120e+01 -3.30985915e+01]
#  [-3.72378808e+01 -4.35135949e+01 -3.72387046e+01 -3.76325840e+01]
#  [-4.35140921e+01 -4.82372154e+01 -4.35140922e+01 -4.37796473e+01]
#  [-4.68394725e+01 -4.68179596e+01 -4.69639026e+01 -4.73843398e+01]]
